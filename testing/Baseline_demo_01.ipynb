# %%
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2

env = gym.make('CartPole-v1')
# Vectorized environments allow to easily multiprocess training
# we demonstrate its usefulness in the next examples
env = DummyVecEnv([lambda: env])  # The algorithms require a vectorized environment to run

model = PPO2(MlpPolicy, env, verbose=1)
# Train the agent
model.learn(total_timesteps=10000)

# Enjoy trained agent
obs = env.reset()
for i in range(1000):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\stable_baselines\common\tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\stable_baselines\common\tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# C:\ProgramData\Anaconda3\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\stable_baselines\common\policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\stable_baselines\common\input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\stable_baselines\common\policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\layers\core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\stable_baselines\common\tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\stable_baselines\common\distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\stable_baselines\common\distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\stable_baselines\ppo2\ppo2.py:190: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\stable_baselines\ppo2\ppo2.py:198: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\stable_baselines\ppo2\ppo2.py:206: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\stable_baselines\ppo2\ppo2.py:240: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\stable_baselines\ppo2\ppo2.py:242: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# --------------------------------------
# | approxkl           | 1.4511777e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0153       |
# | fps                | 195           |
# | n_updates          | 1             |
# | policy_entropy     | 0.69312763    |
# | policy_loss        | -0.0001104665 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 0             |
# | total_timesteps    | 128           |
# | value_loss         | 44.31976      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.11433e-05   |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00927      |
# | fps                | 553           |
# | n_updates          | 2             |
# | policy_entropy     | 0.6931102     |
# | policy_loss        | -0.0032347618 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 0.654         |
# | total_timesteps    | 256           |
# | value_loss         | 51.331863     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0001666879 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.00992      |
# | fps                | 567          |
# | n_updates          | 3            |
# | policy_entropy     | 0.69251794   |
# | policy_loss        | -0.002224532 |
# | serial_timesteps   | 384          |
# | time_elapsed       | 0.886        |
# | total_timesteps    | 384          |
# | value_loss         | 31.981194    |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.000107696935 |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00213       |
# | fps                | 567            |
# | n_updates          | 4              |
# | policy_entropy     | 0.69164914     |
# | policy_loss        | -0.0027550985  |
# | serial_timesteps   | 512            |
# | time_elapsed       | 1.11           |
# | total_timesteps    | 512            |
# | value_loss         | 51.59589       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 5.609632e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0156         |
# | fps                | 567            |
# | n_updates          | 5              |
# | policy_entropy     | 0.6895346      |
# | policy_loss        | -0.00018437475 |
# | serial_timesteps   | 640            |
# | time_elapsed       | 1.34           |
# | total_timesteps    | 640            |
# | value_loss         | 45.061253      |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 9.204595e-06 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.00488     |
# | fps                | 614          |
# | n_updates          | 6            |
# | policy_entropy     | 0.68962026   |
# | policy_loss        | -0.000377169 |
# | serial_timesteps   | 768          |
# | time_elapsed       | 1.57         |
# | total_timesteps    | 768          |
# | value_loss         | 47.813606    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 2.6293324e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0128        |
# | fps                | 562           |
# | n_updates          | 7             |
# | policy_entropy     | 0.68712354    |
# | policy_loss        | -0.0006359243 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 1.78          |
# | total_timesteps    | 896           |
# | value_loss         | 31.693647     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.1247401e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0245        |
# | fps                | 544            |
# | n_updates          | 8              |
# | policy_entropy     | 0.687213       |
# | policy_loss        | -0.00047007645 |
# | serial_timesteps   | 1024           |
# | time_elapsed       | 2              |
# | total_timesteps    | 1024           |
# | value_loss         | 32.230328      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.3536637e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0211        |
# | fps                | 542           |
# | n_updates          | 9             |
# | policy_entropy     | 0.6872933     |
# | policy_loss        | -0.0002577193 |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 2.24          |
# | total_timesteps    | 1152          |
# | value_loss         | 57.799023     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.178822e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00267       |
# | fps                | 545           |
# | n_updates          | 10            |
# | policy_entropy     | 0.6855961     |
# | policy_loss        | -0.0014606591 |
# | serial_timesteps   | 1280          |
# | time_elapsed       | 2.47          |
# | total_timesteps    | 1280          |
# | value_loss         | 55.551624     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00019194587  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.024          |
# | fps                | 558            |
# | n_updates          | 11             |
# | policy_entropy     | 0.68131596     |
# | policy_loss        | -0.00070169894 |
# | serial_timesteps   | 1408           |
# | time_elapsed       | 2.71           |
# | total_timesteps    | 1408           |
# | value_loss         | 44.822556      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 7.2507275e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0235        |
# | fps                | 544           |
# | n_updates          | 12            |
# | policy_entropy     | 0.672378      |
# | policy_loss        | -0.0013008679 |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 2.94          |
# | total_timesteps    | 1536          |
# | value_loss         | 38.099808     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0011547327 |
# | clipfrac           | 0.00390625   |
# | explained_variance | -0.000715    |
# | fps                | 577          |
# | n_updates          | 13           |
# | policy_entropy     | 0.66301143   |
# | policy_loss        | -0.01018486  |
# | serial_timesteps   | 1664         |
# | time_elapsed       | 3.18         |
# | total_timesteps    | 1664         |
# | value_loss         | 26.913002    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0004857747 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.02         |
# | fps                | 567          |
# | n_updates          | 14           |
# | policy_entropy     | 0.65911824   |
# | policy_loss        | -0.004681715 |
# | serial_timesteps   | 1792         |
# | time_elapsed       | 3.4          |
# | total_timesteps    | 1792         |
# | value_loss         | 56.168888    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00027882546 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0416        |
# | fps                | 565           |
# | n_updates          | 15            |
# | policy_entropy     | 0.64614135    |
# | policy_loss        | -0.0010674135 |
# | serial_timesteps   | 1920          |
# | time_elapsed       | 3.63          |
# | total_timesteps    | 1920          |
# | value_loss         | 49.435314     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.42176e-05   |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00948       |
# | fps                | 547           |
# | n_updates          | 16            |
# | policy_entropy     | 0.6369737     |
# | policy_loss        | -0.0013022785 |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 3.85          |
# | total_timesteps    | 2048          |
# | value_loss         | 39.32971      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.8502046e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0488       |
# | fps                | 568           |
# | n_updates          | 17            |
# | policy_entropy     | 0.6580075     |
# | policy_loss        | 0.0003198873  |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 4.09          |
# | total_timesteps    | 2176          |
# | value_loss         | 82.002945     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 7.812658e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0555        |
# | fps                | 547            |
# | n_updates          | 18             |
# | policy_entropy     | 0.6568895      |
# | policy_loss        | -0.00015349174 |
# | serial_timesteps   | 2304           |
# | time_elapsed       | 4.31           |
# | total_timesteps    | 2304           |
# | value_loss         | 47.051537      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.8681937e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00715       |
# | fps                | 562           |
# | n_updates          | 19            |
# | policy_entropy     | 0.6443773     |
# | policy_loss        | -0.000546025  |
# | serial_timesteps   | 2432          |
# | time_elapsed       | 4.55          |
# | total_timesteps    | 2432          |
# | value_loss         | 38.58837      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.1304972e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00501      |
# | fps                | 588           |
# | n_updates          | 20            |
# | policy_entropy     | 0.62499404    |
# | policy_loss        | -0.0007161015 |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 4.78          |
# | total_timesteps    | 2560          |
# | value_loss         | 31.899185     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018474548 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0139       |
# | fps                | 558           |
# | n_updates          | 21            |
# | policy_entropy     | 0.6407747     |
# | policy_loss        | -0.0043137665 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 4.99          |
# | total_timesteps    | 2688          |
# | value_loss         | 63.625526     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.4269846e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.035        |
# | fps                | 546           |
# | n_updates          | 22            |
# | policy_entropy     | 0.6335751     |
# | policy_loss        | -0.00207329   |
# | serial_timesteps   | 2816          |
# | time_elapsed       | 5.22          |
# | total_timesteps    | 2816          |
# | value_loss         | 58.4138       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00021433702 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00234       |
# | fps                | 581           |
# | n_updates          | 23            |
# | policy_entropy     | 0.6190127     |
# | policy_loss        | 0.00075191667 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 5.46          |
# | total_timesteps    | 2944          |
# | value_loss         | 60.58699      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.535497e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0421        |
# | fps                | 555           |
# | n_updates          | 24            |
# | policy_entropy     | 0.6251484     |
# | policy_loss        | -0.0014476617 |
# | serial_timesteps   | 3072          |
# | time_elapsed       | 5.68          |
# | total_timesteps    | 3072          |
# | value_loss         | 86.103455     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00038219694 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00767       |
# | fps                | 545           |
# | n_updates          | 25            |
# | policy_entropy     | 0.6126008     |
# | policy_loss        | -0.0015434665 |
# | serial_timesteps   | 3200          |
# | time_elapsed       | 5.91          |
# | total_timesteps    | 3200          |
# | value_loss         | 40.160164     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.8407596e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0361        |
# | fps                | 558           |
# | n_updates          | 26            |
# | policy_entropy     | 0.5951783     |
# | policy_loss        | -0.0015311313 |
# | serial_timesteps   | 3328          |
# | time_elapsed       | 6.15          |
# | total_timesteps    | 3328          |
# | value_loss         | 57.277164     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 8.546523e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0134         |
# | fps                | 577            |
# | n_updates          | 27             |
# | policy_entropy     | 0.5766378      |
# | policy_loss        | -0.00018157146 |
# | serial_timesteps   | 3456           |
# | time_elapsed       | 6.38           |
# | total_timesteps    | 3456           |
# | value_loss         | 40.783894      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.186541e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00787       |
# | fps                | 575            |
# | n_updates          | 28             |
# | policy_entropy     | 0.5910679      |
# | policy_loss        | -0.00056058005 |
# | serial_timesteps   | 3584           |
# | time_elapsed       | 6.6            |
# | total_timesteps    | 3584           |
# | value_loss         | 50.919605      |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 6.482898e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.0925      |
# | fps                | 569          |
# | n_updates          | 29           |
# | policy_entropy     | 0.60249054   |
# | policy_loss        | 0.0014632749 |
# | serial_timesteps   | 3712         |
# | time_elapsed       | 6.82         |
# | total_timesteps    | 3712         |
# | value_loss         | 52.01244     |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 2.8654613e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0527         |
# | fps                | 571            |
# | n_updates          | 30             |
# | policy_entropy     | 0.6208254      |
# | policy_loss        | -0.00030395912 |
# | serial_timesteps   | 3840           |
# | time_elapsed       | 7.05           |
# | total_timesteps    | 3840           |
# | value_loss         | 54.520576      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.9895579e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0575         |
# | fps                | 595            |
# | n_updates          | 31             |
# | policy_entropy     | 0.5717204      |
# | policy_loss        | -0.00040215504 |
# | serial_timesteps   | 3968           |
# | time_elapsed       | 7.27           |
# | total_timesteps    | 3968           |
# | value_loss         | 70.82913       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 2.2226863e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0496        |
# | fps                | 562            |
# | n_updates          | 32             |
# | policy_entropy     | 0.6175296      |
# | policy_loss        | -0.00046655827 |
# | serial_timesteps   | 4096           |
# | time_elapsed       | 7.49           |
# | total_timesteps    | 4096           |
# | value_loss         | 47.644432      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 8.0073305e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0403        |
# | fps                | 560           |
# | n_updates          | 33            |
# | policy_entropy     | 0.58967245    |
# | policy_loss        | -0.000634931  |
# | serial_timesteps   | 4224          |
# | time_elapsed       | 7.72          |
# | total_timesteps    | 4224          |
# | value_loss         | 48.852005     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.715231e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.000235     |
# | fps                | 544           |
# | n_updates          | 34            |
# | policy_entropy     | 0.58589625    |
# | policy_loss        | -0.0003444875 |
# | serial_timesteps   | 4352          |
# | time_elapsed       | 7.95          |
# | total_timesteps    | 4352          |
# | value_loss         | 51.052563     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.8244582e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0363       |
# | fps                | 546           |
# | n_updates          | 35            |
# | policy_entropy     | 0.6000341     |
# | policy_loss        | 0.0004589192  |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 8.18          |
# | total_timesteps    | 4480          |
# | value_loss         | 67.535095     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.644102e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0801        |
# | fps                | 565           |
# | n_updates          | 36            |
# | policy_entropy     | 0.56628054    |
# | policy_loss        | -0.0005413336 |
# | serial_timesteps   | 4608          |
# | time_elapsed       | 8.42          |
# | total_timesteps    | 4608          |
# | value_loss         | 68.28666      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.600776e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0271        |
# | fps                | 544           |
# | n_updates          | 37            |
# | policy_entropy     | 0.6114602     |
# | policy_loss        | -0.0012209814 |
# | serial_timesteps   | 4736          |
# | time_elapsed       | 8.64          |
# | total_timesteps    | 4736          |
# | value_loss         | 88.83548      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00016448088 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0527       |
# | fps                | 559           |
# | n_updates          | 38            |
# | policy_entropy     | 0.6125358     |
# | policy_loss        | -0.0008757351 |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 8.88          |
# | total_timesteps    | 4864          |
# | value_loss         | 70.398796     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.1809985e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00825       |
# | fps                | 578           |
# | n_updates          | 39            |
# | policy_entropy     | 0.58766854    |
# | policy_loss        | -0.0014447462 |
# | serial_timesteps   | 4992          |
# | time_elapsed       | 9.11          |
# | total_timesteps    | 4992          |
# | value_loss         | 49.711365     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000116541385 |
# | clipfrac           | 0.0            |
# | explained_variance | -0.033         |
# | fps                | 537            |
# | n_updates          | 40             |
# | policy_entropy     | 0.5717531      |
# | policy_loss        | -0.0010237544  |
# | serial_timesteps   | 5120           |
# | time_elapsed       | 9.33           |
# | total_timesteps    | 5120           |
# | value_loss         | 51.735413      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.9998566e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.134         |
# | fps                | 520           |
# | n_updates          | 41            |
# | policy_entropy     | 0.5910359     |
# | policy_loss        | -0.0014149997 |
# | serial_timesteps   | 5248          |
# | time_elapsed       | 9.57          |
# | total_timesteps    | 5248          |
# | value_loss         | 64.544975     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00015392614 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00556      |
# | fps                | 544           |
# | n_updates          | 42            |
# | policy_entropy     | 0.5882216     |
# | policy_loss        | -0.0044405204 |
# | serial_timesteps   | 5376          |
# | time_elapsed       | 9.82          |
# | total_timesteps    | 5376          |
# | value_loss         | 70.078575     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 9.930557e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.06         |
# | fps                | 580          |
# | n_updates          | 43           |
# | policy_entropy     | 0.58038896   |
# | policy_loss        | -0.003967817 |
# | serial_timesteps   | 5504         |
# | time_elapsed       | 10.1         |
# | total_timesteps    | 5504         |
# | value_loss         | 49.27569     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 7.3002295e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00711       |
# | fps                | 580           |
# | n_updates          | 44            |
# | policy_entropy     | 0.57291657    |
# | policy_loss        | -0.0025916821 |
# | serial_timesteps   | 5632          |
# | time_elapsed       | 10.3          |
# | total_timesteps    | 5632          |
# | value_loss         | 62.756134     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014299381 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.138         |
# | fps                | 571           |
# | n_updates          | 45            |
# | policy_entropy     | 0.6369872     |
# | policy_loss        | 0.0009985659  |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 10.5          |
# | total_timesteps    | 5760          |
# | value_loss         | 65.07112      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.7077007e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0288         |
# | fps                | 567            |
# | n_updates          | 46             |
# | policy_entropy     | 0.5751175      |
# | policy_loss        | -0.00039232604 |
# | serial_timesteps   | 5888           |
# | time_elapsed       | 10.7           |
# | total_timesteps    | 5888           |
# | value_loss         | 61.617607      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00020888106 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.145         |
# | fps                | 576           |
# | n_updates          | 47            |
# | policy_entropy     | 0.60329026    |
# | policy_loss        | -0.0021171458 |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 10.9          |
# | total_timesteps    | 6016          |
# | value_loss         | 61.486664     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0003083819 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.163       |
# | fps                | 564          |
# | n_updates          | 48           |
# | policy_entropy     | 0.60052615   |
# | policy_loss        | 0.0021707292 |
# | serial_timesteps   | 6144         |
# | time_elapsed       | 11.2         |
# | total_timesteps    | 6144         |
# | value_loss         | 87.507706    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0031791911 |
# | clipfrac           | 0.013671875  |
# | explained_variance | 0.336        |
# | fps                | 565          |
# | n_updates          | 49           |
# | policy_entropy     | 0.6223664    |
# | policy_loss        | 0.008310713  |
# | serial_timesteps   | 6272         |
# | time_elapsed       | 11.4         |
# | total_timesteps    | 6272         |
# | value_loss         | 57.70505     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00015397338 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0197       |
# | fps                | 582           |
# | n_updates          | 50            |
# | policy_entropy     | 0.59610736    |
# | policy_loss        | -0.0015263805 |
# | serial_timesteps   | 6400          |
# | time_elapsed       | 11.6          |
# | total_timesteps    | 6400          |
# | value_loss         | 84.667145     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0010093589 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.072        |
# | fps                | 585          |
# | n_updates          | 51           |
# | policy_entropy     | 0.57015634   |
# | policy_loss        | -0.00682785  |
# | serial_timesteps   | 6528         |
# | time_elapsed       | 11.8         |
# | total_timesteps    | 6528         |
# | value_loss         | 51.1732      |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00014483904 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.28          |
# | fps                | 553           |
# | n_updates          | 52            |
# | policy_entropy     | 0.58729756    |
# | policy_loss        | 0.00044182735 |
# | serial_timesteps   | 6656          |
# | time_elapsed       | 12.1          |
# | total_timesteps    | 6656          |
# | value_loss         | 80.68872      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0013765212 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.258        |
# | fps                | 609          |
# | n_updates          | 53           |
# | policy_entropy     | 0.60263807   |
# | policy_loss        | 0.0052755326 |
# | serial_timesteps   | 6784         |
# | time_elapsed       | 12.3         |
# | total_timesteps    | 6784         |
# | value_loss         | 71.20868     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 3.3809258e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.113         |
# | fps                | 558           |
# | n_updates          | 54            |
# | policy_entropy     | 0.60432655    |
# | policy_loss        | 0.0009987479  |
# | serial_timesteps   | 6912          |
# | time_elapsed       | 12.5          |
# | total_timesteps    | 6912          |
# | value_loss         | 80.26854      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00040402645 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00196      |
# | fps                | 551           |
# | n_updates          | 55            |
# | policy_entropy     | 0.587082      |
# | policy_loss        | -0.0025744615 |
# | serial_timesteps   | 7040          |
# | time_elapsed       | 12.7          |
# | total_timesteps    | 7040          |
# | value_loss         | 60.575817     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00017898763  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0715         |
# | fps                | 562            |
# | n_updates          | 56             |
# | policy_entropy     | 0.56732297     |
# | policy_loss        | -0.00025015988 |
# | serial_timesteps   | 7168           |
# | time_elapsed       | 13             |
# | total_timesteps    | 7168           |
# | value_loss         | 55.667953      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.392657e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0679        |
# | fps                | 557           |
# | n_updates          | 57            |
# | policy_entropy     | 0.61711866    |
# | policy_loss        | -0.0018388979 |
# | serial_timesteps   | 7296          |
# | time_elapsed       | 13.2          |
# | total_timesteps    | 7296          |
# | value_loss         | 66.04634      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.5034893e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0144        |
# | fps                | 571           |
# | n_updates          | 58            |
# | policy_entropy     | 0.5834419     |
# | policy_loss        | -0.0008259902 |
# | serial_timesteps   | 7424          |
# | time_elapsed       | 13.4          |
# | total_timesteps    | 7424          |
# | value_loss         | 59.006016     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.0901605e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.354         |
# | fps                | 585           |
# | n_updates          | 59            |
# | policy_entropy     | 0.6108231     |
# | policy_loss        | 0.00012545031 |
# | serial_timesteps   | 7552          |
# | time_elapsed       | 13.7          |
# | total_timesteps    | 7552          |
# | value_loss         | 53.110172     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.6384852e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.362          |
# | fps                | 560            |
# | n_updates          | 60             |
# | policy_entropy     | 0.5858736      |
# | policy_loss        | -0.00069384975 |
# | serial_timesteps   | 7680           |
# | time_elapsed       | 13.9           |
# | total_timesteps    | 7680           |
# | value_loss         | 76.120544      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0008456882  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.215         |
# | fps                | 598           |
# | n_updates          | 61            |
# | policy_entropy     | 0.59529305    |
# | policy_loss        | -0.0040613823 |
# | serial_timesteps   | 7808          |
# | time_elapsed       | 14.1          |
# | total_timesteps    | 7808          |
# | value_loss         | 58.52213      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00017306596 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.205         |
# | fps                | 604           |
# | n_updates          | 62            |
# | policy_entropy     | 0.58954364    |
# | policy_loss        | 0.0015179908  |
# | serial_timesteps   | 7936          |
# | time_elapsed       | 14.3          |
# | total_timesteps    | 7936          |
# | value_loss         | 54.401848     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.2702984e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0176        |
# | fps                | 588           |
# | n_updates          | 63            |
# | policy_entropy     | 0.60206854    |
# | policy_loss        | 0.00037824316 |
# | serial_timesteps   | 8064          |
# | time_elapsed       | 14.5          |
# | total_timesteps    | 8064          |
# | value_loss         | 77.644905     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.0641957e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0884        |
# | fps                | 580           |
# | n_updates          | 64            |
# | policy_entropy     | 0.6044491     |
# | policy_loss        | 0.0016053477  |
# | serial_timesteps   | 8192          |
# | time_elapsed       | 14.7          |
# | total_timesteps    | 8192          |
# | value_loss         | 50.958244     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.110533e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0517         |
# | fps                | 549            |
# | n_updates          | 65             |
# | policy_entropy     | 0.5935074      |
# | policy_loss        | -5.8549456e-05 |
# | serial_timesteps   | 8320           |
# | time_elapsed       | 15             |
# | total_timesteps    | 8320           |
# | value_loss         | 54.375744      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.9920068e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0282        |
# | fps                | 606            |
# | n_updates          | 66             |
# | policy_entropy     | 0.5931547      |
# | policy_loss        | -1.1212076e-05 |
# | serial_timesteps   | 8448           |
# | time_elapsed       | 15.2           |
# | total_timesteps    | 8448           |
# | value_loss         | 75.16388       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00056389347 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.25          |
# | fps                | 577           |
# | n_updates          | 67            |
# | policy_entropy     | 0.5982307     |
# | policy_loss        | -0.0016859106 |
# | serial_timesteps   | 8576          |
# | time_elapsed       | 15.4          |
# | total_timesteps    | 8576          |
# | value_loss         | 73.89145      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0011687155   |
# | clipfrac           | 0.005859375    |
# | explained_variance | 0.137          |
# | fps                | 583            |
# | n_updates          | 68             |
# | policy_entropy     | 0.59411836     |
# | policy_loss        | -0.00013139099 |
# | serial_timesteps   | 8704           |
# | time_elapsed       | 15.6           |
# | total_timesteps    | 8704           |
# | value_loss         | 63.875504      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00043377327 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.314         |
# | fps                | 562           |
# | n_updates          | 69            |
# | policy_entropy     | 0.6111533     |
# | policy_loss        | 0.00014236453 |
# | serial_timesteps   | 8832          |
# | time_elapsed       | 15.9          |
# | total_timesteps    | 8832          |
# | value_loss         | 53.976562     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00010633378 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.156         |
# | fps                | 580           |
# | n_updates          | 70            |
# | policy_entropy     | 0.61761343    |
# | policy_loss        | -0.0021820595 |
# | serial_timesteps   | 8960          |
# | time_elapsed       | 16.1          |
# | total_timesteps    | 8960          |
# | value_loss         | 59.151016     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.9254795e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0411        |
# | fps                | 580           |
# | n_updates          | 71            |
# | policy_entropy     | 0.5922387     |
# | policy_loss        | 0.0005274775  |
# | serial_timesteps   | 9088          |
# | time_elapsed       | 16.3          |
# | total_timesteps    | 9088          |
# | value_loss         | 72.505936     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00022342626 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.192         |
# | fps                | 585           |
# | n_updates          | 72            |
# | policy_entropy     | 0.5865622     |
# | policy_loss        | 0.0004399931  |
# | serial_timesteps   | 9216          |
# | time_elapsed       | 16.5          |
# | total_timesteps    | 9216          |
# | value_loss         | 70.40055      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0015325508 |
# | clipfrac           | 0.0078125    |
# | explained_variance | -0.338       |
# | fps                | 567          |
# | n_updates          | 73           |
# | policy_entropy     | 0.5993647    |
# | policy_loss        | 0.0003600096 |
# | serial_timesteps   | 9344         |
# | time_elapsed       | 16.7         |
# | total_timesteps    | 9344         |
# | value_loss         | 74.73731     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 6.671819e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0115       |
# | fps                | 558          |
# | n_updates          | 74           |
# | policy_entropy     | 0.58274364   |
# | policy_loss        | 0.0013002749 |
# | serial_timesteps   | 9472         |
# | time_elapsed       | 17           |
# | total_timesteps    | 9472         |
# | value_loss         | 56.889946    |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 5.563142e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.246          |
# | fps                | 527            |
# | n_updates          | 75             |
# | policy_entropy     | 0.60384405     |
# | policy_loss        | -0.00093651016 |
# | serial_timesteps   | 9600           |
# | time_elapsed       | 17.2           |
# | total_timesteps    | 9600           |
# | value_loss         | 49.488792      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 6.133065e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0413        |
# | fps                | 556           |
# | n_updates          | 76            |
# | policy_entropy     | 0.58432406    |
# | policy_loss        | 0.00027262117 |
# | serial_timesteps   | 9728          |
# | time_elapsed       | 17.4          |
# | total_timesteps    | 9728          |
# | value_loss         | 50.73436      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.9053053e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.301         |
# | fps                | 536           |
# | n_updates          | 77            |
# | policy_entropy     | 0.6169221     |
# | policy_loss        | 0.0001875622  |
# | serial_timesteps   | 9856          |
# | time_elapsed       | 17.7          |
# | total_timesteps    | 9856          |
# | value_loss         | 47.185356     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.5227335e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.263         |
# | fps                | 501           |
# | n_updates          | 78            |
# | policy_entropy     | 0.60756123    |
# | policy_loss        | -0.0002459744 |
# | serial_timesteps   | 9984          |
# | time_elapsed       | 17.9          |
# | total_timesteps    | 9984          |
# | value_loss         | 50.643513     |
# --------------------------------------
